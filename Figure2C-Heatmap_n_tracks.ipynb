# %%
# ! mkdir genes_allana
# ! scp newhpc:/home/allana.schooley-umw/as38w/Ranger/RNAseq/geneannotation/hg38.refGene.genpred.f.sorted.bed ./genes_allana/
# ! scp newhpc:/home/allana.schooley-umw/as38w/Ranger/RNAseq/geneannotation/hg38.refGene.genpred.r.sorted.bed ./genes_allana/
# ! scp newhpc:/home/allana.schooley-umw/as38w/Ranger/RNAseq/geneannotation/hg38.refGene.genpred.atRNAseq.fpkmg1.f.sorted.bed ./genes_allana/
# ! scp newhpc:/home/allana.schooley-umw/as38w/Ranger/RNAseq/geneannotation/hg38.refGene.genpred.atRNAseq.fpkmg1.r.sorted.bed ./genes_allana/
# ! head genes_allana/hg38.refGene.genpred.f.sorted.bed

# %%
# from BCBio.GFF import GFFExaminer
# from BCBio import GFF
# import pprint
# from dna_features_viewer import BiopythonTranslator
# ! head /data/sergpolly/hg38.gff
# in_file = "/data/sergpolly/hg38.gff"
# # examiner = GFFExaminer()
# # in_handle = open(in_file)
# # pprint.pprint(examiner.parent_child_map(in_handle))
# # in_handle.close
# examiner = GFFExaminer()
# in_handle = open(in_file)
# pprint.pprint(examiner.available_limits(in_handle))
# in_handle.close()


# in_file = "/data/sergpolly/hg38.gff"
# # examiner = GFFExaminer()
# # in_handle = open(in_file)
# # pprint.pprint(examiner.available_limits(in_handle))
# # in_handle.close()

# _gff_filter = dict(
#     gff_id=['NC_000006.12'],  # chr6 - maybe ?!
#     # gff_source=['RefSeq'],
#     gff_type=["gene"],
# )

# in_handle = open(in_file)
# for rec in GFF.parse( in_handle, limit_info=_gff_filter ):
#     _chr6genes = rec
#     break
# in_handle.close()

# # # # ...
# # region1_10 = ('chr6', 129100000-230_000, 130500000+30_000)
# # region2_10 = ('chr6', 136100000-45_000, 138200000+45_000)


# from dna_features_viewer import BiopythonTranslator
# # record = SeqIO.read("example_sequence.gb", "genbank")

# fplus = lambda f: f.location.strand > 0
# fminus = lambda f: f.location.strand < 0
# fsize = lambda f: (f.location.end - f.location.start)>15_000

# translator_plus = BiopythonTranslator(features_filters=[fplus, fsize])
# translator_minus = BiopythonTranslator(features_filters=[fminus, fsize])

# %%
# _start, _end = 136100000, 138200000
# _region = ('chr6', _start, _end)

# gfs_fwd = []
# for _row in bioframe.merge(bioframe.select(_fwd, _region)).itertuples(index=False):
#     # print(_row)
#     _gf = GraphicFeature(
#         start=int(_row.start),
#         end=int(_row.end),
#         strand=1,
#         color='black',
#         **gfargs,
#     )
#     gfs_fwd.append(_gf)


# gfs_rev = []
# for _row in bioframe.merge(bioframe.select(_rev, _region)).itertuples(index=False):
#     # print(_row)
#     _gf = GraphicFeature(
#         start=int(_row.start),
#         end=int(_row.end),
#         strand=-1,
#         color='black',
#         **gfargs
#    )
#     gfs_rev.append(_gf)



# gfs_act_fwd = []
# for _row in bioframe.merge(bioframe.select(_fwd_act, _region)).itertuples(index=False):
#     # print(_row)
#     _gf = GraphicFeature(
#         start=int(_row.start),
#         end=int(_row.end),
#         strand=1,
#         color='green',
#         **gfargs,
#     )
#     gfs_act_fwd.append(_gf)


# gfs_act_rev = []
# for _row in bioframe.merge(bioframe.select(_rev_act, _region)).itertuples(index=False):
#     # print(_row)
#     _gf = GraphicFeature(
#         start=int(_row.start),
#         end=int(_row.end),
#         strand=-1,
#         color='green',
#         **gfargs
#    )
#     gfs_act_rev.append(_gf)




# _hui_fwd = GraphicRecord(
#     sequence_length=(_end-_start+1),
#     features=gfs_fwd,
# )

# _hui_rev = GraphicRecord(
#     sequence_length=(_end-_start+1),
#     features=gfs_rev,
# )


# _hui_act_fwd = GraphicRecord(
#     sequence_length=(_end-_start+1),
#     features=gfs_act_fwd,
# )

# _hui_act_rev = GraphicRecord(
#     sequence_length=(_end-_start+1),
#     features=gfs_act_rev,
# )

# # f,ax = plt.subplots(1,1)
# ax, _ = _hui_fwd.plot(
#     x_lim=(_start, _end),
#     level_offset=-0.5,
#     **plotargs,
# )

# _hui_rev.plot(
#     ax=ax,
#     x_lim=(_start, _end),
#     level_offset=0.5,
#     **plotargs,
# )


# _hui_act_fwd.plot(
#     ax=ax,
#     x_lim=(_start, _end),
#     level_offset=-0.5,
#     **plotargs,
# )
# _hui_act_rev.plot(
#     ax=ax,
#     x_lim=(_start, _end),
#     level_offset=0.5,
#     **plotargs,
# )
# ax.set_ylim(-1,1)
# ax.set_axis_on()
# # ax.set_yticks([-1,0,1,2,3,4,5])

# %%
import pandas as pd
import numpy as np
from itertools import chain

# Hi-C utilities imports:
import cooler
import bioframe
import cooltools
from cooltools.lib.numutils import fill_diag

# Visualization imports:
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib.colors import PowerNorm
from matplotlib import cm
# %matplotlib widget
# %matplotlib inline

import matplotlib.patches as patches
from matplotlib.ticker import EngFormatter
from mpl_toolkits.axes_grid1 import make_axes_locatable
from cooltools.lib import plotting

from itertools import cycle

# # from ipywidgets import interact, fixed
# from ipywidgets import interact, interactive, fixed, interact_manual
# import ipywidgets as widgets

# enable editable text ...
mpl.rcParams["pdf.fonttype"]=42
mpl.rcParams["svg.fonttype"]='none'
mpl.rcParams['axes.linewidth'] = 0.5

# %% [markdown]
# ### Import modified "guts" of the dotfinder submodule from `helper_func` file

# %%
from helper_func import draw_kernel

# turns out still need some of the dotfinder guts in here
from cooltools.api.dotfinder import bp_to_bins, generate_tiles_diag_band
from cooltools.lib.numutils import LazyToeplitz
from cooltools.lib.common import assign_regions

from functools import partial
from data_catalog import bws, bws_vlim, telo_dict

import datashader as ds, xarray as xr
from datashader import transfer_functions as tf, reductions as rd
from datashader.mpl_ext import dsshow, alpha_colormap

from matplotlib.cm import YlOrRd
import matplotlib.image as mpimg

from palettable.scientific import sequential
lajolla_r = sequential.LaJolla_10_r.get_mpl_colormap()
bilbao_r = sequential.Bilbao_20_r.get_mpl_colormap()
batlow_r = sequential.Batlow_20_r.get_mpl_colormap()
devon_r = sequential.Devon_20_r.get_mpl_colormap()
davos_r = sequential.Davos_20_r.get_mpl_colormap()
# fall_cmap = fall
lajolla = sequential.LaJolla_10.get_mpl_colormap()
bilbao = sequential.Bilbao_20.get_mpl_colormap()
batlow = sequential.Batlow_20.get_mpl_colormap()
devon = sequential.Devon_20.get_mpl_colormap()
davos = sequential.Davos_20.get_mpl_colormap()

imola_r = sequential.Imola_20_r.get_mpl_colormap()
imola = sequential.Imola_20.get_mpl_colormap()

nuuk_r = sequential.Nuuk_20_r.get_mpl_colormap()
nuuk = sequential.Nuuk_20.get_mpl_colormap()

hawaii_r = sequential.Hawaii_20_r.get_mpl_colormap()
hawaii = sequential.Hawaii_20.get_mpl_colormap()

oleron_r = sequential.Oleron_20_r.get_mpl_colormap()
oleron = sequential.Oleron_20.get_mpl_colormap()

oslo_r = sequential.Oslo_20_r.get_mpl_colormap()
oslo = sequential.Oslo_20.get_mpl_colormap()

bamako_r = sequential.Bamako_20_r.get_mpl_colormap()
bamako = sequential.Bamako_20.get_mpl_colormap()

grayc_r = sequential.GrayC_20_r.get_mpl_colormap()
grayc = sequential.GrayC_20.get_mpl_colormap()

lapaz_r = sequential.LaPaz_20_r.get_mpl_colormap()
lapaz = sequential.LaPaz_20.get_mpl_colormap()

# %%
! ls genes_allana

# %%
from dna_features_viewer import GraphicRecord, GraphicFeature
fwd_args = dict(
    label=None,
    thickness=4,
    linewidth=0,
    strand=1,
    color="tab:red",
)
rev_args = dict(
    label=None,
    thickness=4,
    linewidth=0,
    strand=-1,
    color="tab:blue",
)

plotargs = dict(
    with_ruler=False,
    draw_line=False,
)

_fwd = bioframe.read_table("genes_allana/hg38.refGene.genpred.f.sorted.bed",schema="bed12").eval("size = end - start").query("size > 8_000")
_rev = bioframe.read_table("genes_allana/hg38.refGene.genpred.r.sorted.bed",schema="bed12").eval("size = end - start").query("size > 8_000")

_fwd_act = bioframe.read_table("genes_allana/hg38.refGene.genpred.atRNAseq.fpkmg1.f.sorted.bed",schema="bed12").eval("size = end - start").query("size > 8_000")
_rev_act = bioframe.read_table("genes_allana/hg38.refGene.genpred.atRNAseq.fpkmg1.r.sorted.bed",schema="bed12").eval("size = end - start").query("size > 8_000")

# %%
_fwd_inact = bioframe.setdiff(
    _fwd,
    _fwd_act
)

_rev_inact = bioframe.setdiff(
    _rev,
    _rev_act
)

# %%
import numpy as np
from scipy import interpolate
# https://stackoverflow.com/questions/6518811/interpolate-nan-values-in-a-numpy-array
def fill_nan(A):
    '''
    interpolate to fill nan values
    '''
    inds = np.arange(A.shape[0])
    good = np.where(np.isfinite(A))
    f = interpolate.interp1d(inds[good], A[good],bounds_error=False)
    B = np.where(np.isfinite(A),A,f(inds))
    return B

# %%
# import matplotlib.pyplot as plt
import bbi
import matplotlib.lines as lines
from matplotlib.lines import Line2D
from matplotlib.patches import ConnectionPatch, Rectangle
from mpl_toolkits.axes_grid1 import Divider, Size
from mpl_toolkits.axes_grid1.inset_locator import BboxConnector

# manual colorbar example ...
# #
# cax = divider.append_axes("right", size=0.1, pad=0.05)
# plt.colorbar(
#     cm.ScalarMappable(norm=PowerNorm(1/3., vmin=vmin, vmax=vmax), cmap=mycmap),
#     cax=cax,
# )

import matplotlib.patches as mpatches
import matplotlib.path as mpath

# import matplotlib.pyplot as plt
import bbi
import matplotlib.lines as lines
from matplotlib.lines import Line2D
from matplotlib.patches import ConnectionPatch, Rectangle
from mpl_toolkits.axes_grid1 import Divider, Size
from mpl_toolkits.axes_grid1.inset_locator import BboxConnector


# draw 2 arm chromosome ....
def get_chrom_path(
    x0y0,  # position of the centromere ...
    parm,  # p arm length
    qarm,  # q arm length
    width,  # width
    color="grey",
):
    # unpack coordinates of the center (centromere)
    x0, y0 = x0y0

    # calculate half width
    hw = 0.5*width

    dtelo = 0.5*width
    dxcent = 0.2*width
    dycent = 0.5*width

    # Prepare the data for the PathPatch below.
    Path = mpath.Path
    codes, verts = zip(*[
        # p-arm up:
        (Path.MOVETO, [x0-hw, y0+dycent]),
        (Path.LINETO, [x0-hw, y0+parm-dtelo]),
        # p-telomere curve:
        (Path.CURVE3, [x0-hw, y0+parm]),
        (Path.CURVE3, [x0, y0+parm]),
        (Path.CURVE3, [x0+hw, y0+parm]),
        (Path.CURVE3, [x0+hw, y0+parm-dtelo]),
        # p-arm down:
        (Path.LINETO, [x0+hw, y0+dycent]),
        # centromere S curve (right)
        # (1S)
        (Path.CURVE4, [x0+hw, y0+0.5*dycent]),
        (Path.CURVE4, [x0+hw-dxcent, y0+0.5*dycent]),
        (Path.CURVE4, [x0+hw-dxcent, y0]),
        # (2S)
        (Path.CURVE4, [x0+hw-dxcent, y0-0.5*dycent]),
        (Path.CURVE4, [x0+hw, y0-0.5*dycent]),
        (Path.CURVE4, [x0+hw, y0-dycent]),
        # q-arm down
        (Path.LINETO, [x0+hw, y0-qarm+dtelo]),
        # q-telomere curve:
        (Path.CURVE3, [x0+hw, y0-qarm]),
        (Path.CURVE3, [x0, y0-qarm]),
        (Path.CURVE3, [x0-hw, y0-qarm]),
        (Path.CURVE3, [x0-hw, y0-qarm+dtelo]),
        # q-arm up
        (Path.LINETO, [x0-hw, y0-dycent]),
        # centromere S curve (left)
        (Path.CURVE4, [x0-hw, y0-0.5*dycent]),
        (Path.CURVE4, [x0-hw+dxcent, y0-0.5*dycent]),
        (Path.CURVE4, [x0-hw+dxcent, y0]),
        (Path.CURVE4, [x0-hw+dxcent, y0+0.5*dycent]),
        (Path.CURVE4, [x0-hw, y0+0.5*dycent]),
        (Path.CURVE4, [x0-hw, y0+dycent]),
        (Path.CLOSEPOLY, [x0-hw, y0+dycent]),
    ])

    chrom = mpatches.PathPatch(mpath.Path(verts, codes), ec="none")
    chrom.set(color=color)
    return chrom






# draw 2 arm chromosome ....
def get_chrom_path_wpathes(
    x0y0,  # position of the centromere ...
    parm,  # p arm length
    qarm,  # q arm length
    width,  # width
    color="grey",
    patches=None,  # [(_arm, _from, _to, pcolor)]
):
    # unpack coordinates of the center (centromere)
    x0, y0 = x0y0

    # calculate half width
    hw = 0.5*width

    dtelo = 0.5*width
    dxcent = 0.2*width
    dycent = 0.5*width

    # Prepare the data for the PathPatch below.
    Path = mpath.Path
    codes, verts = zip(*[
        # p-arm up:
        (Path.MOVETO, [x0-hw, y0+dycent]),
        (Path.LINETO, [x0-hw, y0+parm-dtelo]),
        # p-telomere curve:
        (Path.CURVE3, [x0-hw, y0+parm]),
        (Path.CURVE3, [x0, y0+parm]),
        (Path.CURVE3, [x0+hw, y0+parm]),
        (Path.CURVE3, [x0+hw, y0+parm-dtelo]),
        # p-arm down:
        (Path.LINETO, [x0+hw, y0+dycent]),
        # centromere S curve (right)
        # (1S)
        (Path.CURVE4, [x0+hw, y0+0.5*dycent]),
        (Path.CURVE4, [x0+hw-dxcent, y0+0.5*dycent]),
        (Path.CURVE4, [x0+hw-dxcent, y0]),
        # (2S)
        (Path.CURVE4, [x0+hw-dxcent, y0-0.5*dycent]),
        (Path.CURVE4, [x0+hw, y0-0.5*dycent]),
        (Path.CURVE4, [x0+hw, y0-dycent]),
        # q-arm down
        (Path.LINETO, [x0+hw, y0-qarm+dtelo]),
        # q-telomere curve:
        (Path.CURVE3, [x0+hw, y0-qarm]),
        (Path.CURVE3, [x0, y0-qarm]),
        (Path.CURVE3, [x0-hw, y0-qarm]),
        (Path.CURVE3, [x0-hw, y0-qarm+dtelo]),
        # q-arm up
        (Path.LINETO, [x0-hw, y0-dycent]),
        # centromere S curve (left)
        (Path.CURVE4, [x0-hw, y0-0.5*dycent]),
        (Path.CURVE4, [x0-hw+dxcent, y0-0.5*dycent]),
        (Path.CURVE4, [x0-hw+dxcent, y0]),
        (Path.CURVE4, [x0-hw+dxcent, y0+0.5*dycent]),
        (Path.CURVE4, [x0-hw, y0+0.5*dycent]),
        (Path.CURVE4, [x0-hw, y0+dycent]),
        (Path.CLOSEPOLY, [x0-hw, y0+dycent]),
    ])

    chrom = mpatches.PathPatch(mpath.Path(verts, codes), ec="none")
    chrom.set(color=color)

    patches_to_draw = []
    if patches is not None:
        # go over patches ...
        for _arm, _from, _to, pcolor in patches:
            hw = hw + 0.005
            if _arm == "q":
                codes, verts = zip(*[
                    # rectangle
                    (Path.MOVETO, [x0-hw, y0-_from]),
                    (Path.LINETO, [x0-hw, y0-_to]),
                    (Path.LINETO, [x0+hw, y0-_to]),
                    (Path.LINETO, [x0+hw, y0-_from]),
                    (Path.CLOSEPOLY, [x0-hw, y0-_from]),
                ])
            elif _arm == "p":
                codes, verts = zip(*[
                    # rectangle
                    (Path.MOVETO, [x0-hw, y0+_from]),
                    (Path.LINETO, [x0-hw, y0+_to]),
                    (Path.LINETO, [x0+hw, y0+_to]),
                    (Path.LINETO, [x0+hw, y0+_from]),
                    (Path.CLOSEPOLY, [x0-hw, y0+_from]),
                ])
            else:
                raise("arms !!!")
            part = mpatches.PathPatch(mpath.Path(verts, codes), ec="none")
            part.set(color=pcolor)
            patches_to_draw.append(part)

    return chrom, patches_to_draw





# draw 2 arm chromosome ....
def get_chrom_path_highlight(
    x0y0,  # position of the centromere ...
    parm,  # p arm length
    qarm,  # q arm length
    width,  # width
    color="grey",
    pshade=0,  # fraction of p arm to be highlighted
    qshade=0,  # fraction of q arm to be highlighted
    colorp="black",
    colorq="black",
):
    """
    a function that also highlight terminal part of
    p and q arms ...
    """
    # unpack coordinates of the center (centromere)
    x0, y0 = x0y0

    # calculate half width
    hw = 0.5*width

    dtelo = 0.5*width
    dxcent = 0.2*width
    dycent = 0.5*width

    # Prepare the data for the PathPatch below.
    Path = mpath.Path
    codes, verts = zip(*[
        # p-arm up:
        (Path.MOVETO, [x0-hw, y0+dycent]),
        (Path.LINETO, [x0-hw, y0+parm-dtelo]),
        # p-telomere curve:
        (Path.CURVE3, [x0-hw, y0+parm]),
        (Path.CURVE3, [x0, y0+parm]),
        (Path.CURVE3, [x0+hw, y0+parm]),
        (Path.CURVE3, [x0+hw, y0+parm-dtelo]),
        # p-arm down:
        (Path.LINETO, [x0+hw, y0+dycent]),
        # centromere S curve (right)
        # (1S)
        (Path.CURVE4, [x0+hw, y0+0.5*dycent]),
        (Path.CURVE4, [x0+hw-dxcent, y0+0.5*dycent]),
        (Path.CURVE4, [x0+hw-dxcent, y0]),
        # (2S)
        (Path.CURVE4, [x0+hw-dxcent, y0-0.5*dycent]),
        (Path.CURVE4, [x0+hw, y0-0.5*dycent]),
        (Path.CURVE4, [x0+hw, y0-dycent]),
        # q-arm down
        (Path.LINETO, [x0+hw, y0-qarm+dtelo]),
        # q-telomere curve:
        (Path.CURVE3, [x0+hw, y0-qarm]),
        (Path.CURVE3, [x0, y0-qarm]),
        (Path.CURVE3, [x0-hw, y0-qarm]),
        (Path.CURVE3, [x0-hw, y0-qarm+dtelo]),
        # q-arm up
        (Path.LINETO, [x0-hw, y0-dycent]),
        # centromere S curve (left)
        (Path.CURVE4, [x0-hw, y0-0.5*dycent]),
        (Path.CURVE4, [x0-hw+dxcent, y0-0.5*dycent]),
        (Path.CURVE4, [x0-hw+dxcent, y0]),
        (Path.CURVE4, [x0-hw+dxcent, y0+0.5*dycent]),
        (Path.CURVE4, [x0-hw, y0+0.5*dycent]),
        (Path.CURVE4, [x0-hw, y0+dycent]),
        (Path.CLOSEPOLY, [x0-hw, y0+dycent]),
    ])
    chrom = mpatches.PathPatch(mpath.Path(verts, codes), ec="none")
    chrom.set(color=color)

    hw = hw + 0.005
    if pshade > 0:
        dy_pshade = (1.0-pshade)*parm
        if dy_pshade < dycent:
            dy_pshade = dycent
        # p -arm highlight
        codes, verts = zip(*[
            # p-arm up:
            (Path.MOVETO, [x0-hw, y0+dy_pshade]),
            (Path.LINETO, [x0-hw, y0+parm-dtelo]),
            # p-telomere curve:
            (Path.CURVE3, [x0-hw, y0+parm]),
            (Path.CURVE3, [x0, y0+parm]),
            (Path.CURVE3, [x0+hw, y0+parm]),
            (Path.CURVE3, [x0+hw, y0+parm-dtelo]),
            # p-arm down:
            (Path.LINETO, [x0+hw, y0+dy_pshade]),
            (Path.CLOSEPOLY, [x0-hw, y0+dy_pshade]),
        ])
        part = mpatches.PathPatch(mpath.Path(verts, codes), ec="none")
        part.set(color=colorp)
    else:
        part = None
        dy_pshade = 0

    if qshade > 0:
        # Prepare the data for the PathPatch below.
        dy_qshade = (1.0-qshade)*qarm
        if dy_qshade < dycent:
            dy_qshade = dycent
        codes, verts = zip(*[
            (Path.MOVETO, [x0+hw, y0-dy_qshade]),
            # q-arm down
            (Path.LINETO, [x0+hw, y0-qarm+dtelo]),
            # q-telomere curve:
            (Path.CURVE3, [x0+hw, y0-qarm]),
            (Path.CURVE3, [x0, y0-qarm]),
            (Path.CURVE3, [x0-hw, y0-qarm]),
            (Path.CURVE3, [x0-hw, y0-qarm+dtelo]),
            # q-arm up
            (Path.LINETO, [x0-hw, y0-dy_qshade]),
            (Path.CLOSEPOLY, [x0+hw, y0-dy_qshade]),
        ])
        qart = mpatches.PathPatch(mpath.Path(verts, codes), ec="none")
        qart.set(color=colorq)
    else:
        qart = None
        dy_qshade = 0

    return chrom, (part, y0+dy_pshade), (qart, y0-dy_qshade)

# %% [markdown]
# ### pick a dataset and binsize to work on ...

# %%
# ! ls /data/proj_sync/data_ranger/finalcoolers_mega/ranGAP1-aux-G1s-MEGA.hg38.mapq_30.1000.mcool

# 10 kb is a resolution at which one can clearly see "dots":
binsize10 = 10_000
# cooler files that we'll work on :
telo_clrs10 = { _k: cooler.Cooler(f"{_path}::/resolutions/{binsize10}") for _k, _path in telo_dict.items() }

# 25 and 50 ....
binsize25 = 25_000
# cooler files that we'll work on :
telo_clrs25 = { _k: cooler.Cooler(f"{_path}::/resolutions/{binsize25}") for _k, _path in telo_dict.items() }

binsize50 = 50_000
# cooler files that we'll work on :
telo_clrs50 = { _k: cooler.Cooler(f"{_path}::/resolutions/{binsize50}") for _k, _path in telo_dict.items() }

# %% [markdown]
# ## Define chromosome arms just in case ...

# %%
# define genomic view that will be used to call dots and pre-compute expected

# Use bioframe to fetch the genomic features from the UCSC.
hg38_chromsizes = bioframe.fetch_chromsizes('hg38')
hg38_cens = bioframe.fetch_centromeres('hg38')
hg38_arms_full = bioframe.make_chromarms(hg38_chromsizes, hg38_cens)
# # remove "bad" chromosomes and near-empty arms ...
included_arms = hg38_arms_full["name"].to_list()[:44] # all autosomal ones ...
hg38_arms = hg38_arms_full[hg38_arms_full["name"].isin(included_arms)].reset_index(drop=True)
arms_dict = hg38_arms_full.set_index("name").eval("(end - start)//1000000").to_dict()

# %% [markdown]
# ### generate some bintables for cres and such ...

# %%
# generate some binsized bins
clr_bins10 = cooler.binnify(hg38_chromsizes, binsize10)
clr_bins10 = clr_bins10[~clr_bins10["chrom"].isin(["chrX","chrY","chrM"])]
# now annotate those bins with useful info - e.g. ID anchors ...
display(clr_bins10.head(2))
display(clr_bins10.tail(2))

# %% [markdown]
# ## Figure out anchors drawing and highlighting here ...

# %%
id_anchor_fnames = {
    "mega_2X_enrichment": "ID_anchors/mega_2X_enrichment.fourth_mega.max_size.bed",
    "5hr_2X_enrichment_old": "ID_anchors/5hr_2X_enrichment.second_bulk.max_size.bed",
    "5hr_2X_enrichment": "ID_anchors/5hr_2X_enrichment.pixel_derived.bed",
    "5hr_2X_enrichment_nosing": "ID_anchors/5hr_2X_enrichment.pixel_derived.no_singletons.bed",
    "5hr_2X_enrichment_signal": "ID_anchors/5hr_2X_enrichment.pixel_derived.signal_peaks.bed",
    "10hr_2X_enrichment_signal": "ID_anchors/10hrs_2X_enrichment.pixel_derived.signal_peaks.bed",
    "N93p5_2X_enrichment_signal": "ID_anchors/N93p5_2X_enrichment.pixel_derived.signal_peaks.bed",
    "pCyto_2X_enrichment_signal": "ID_anchors/pCyto_2X_enrichment.pixel_derived.signal_peaks.bed",
    "mCyto_2X_enrichment_signal": "ID_anchors/mCyto_2X_enrichment.pixel_derived.signal_peaks.bed",
    "mega_3X_enrichment": "ID_anchors/mega_3X_enrichment.fifth_mega3x.max_size.bed",
    "MEGA_2X_enrichment": "ID_anchors/MEGAp5_2X_enrichment.pixel_derived.signal_peaks.bed",
    "MEGAN93_2X_enrichment": "ID_anchors/MEGAN93p5_2X_enrichment.pixel_derived.signal_peaks.bed",
    "MEGAminus_2X_enrichment": "ID_anchors/MEGA_minus_ctrl_2X_enrichment.pixel_derived.signal_peaks.bed",
    "cyto_2x_enrichment": "ID_anchors/cyto_2x_enrichment.third_mCyto.max_size.bed",
}

id_anchors_dict = {}
for id_name, fname in id_anchor_fnames.items():
    id_anchors_dict[id_name] = pd.read_csv(fname, sep="\t")
    # ...
    print(f"loaded {len(id_anchors_dict[id_name]):5d} ID anchors {id_name:>20} in BED format ...")

_anchors = id_anchors_dict["5hr_2X_enrichment_signal"]

# we need bins/pixels for plotting - instead of genomic coordinates ...

# need a reference cooler for that to do genomic coords -> bins:
_clr = telo_clrs10["m5hR1R2"]
# doing that using clr.offset and clr.extent functionality:
_anchors["bin_id"] = _anchors[['chrom', 'peak_start', 'peak_end']].apply(_clr.offset, axis=1, result_type="expand")
_anchors["bin_width"] = _anchors[['chrom', 'peak_start', 'peak_end']] \
    .apply(_clr.extent, axis=1, result_type="expand") \
    .apply(np.diff, axis=1, result_type="expand")[0]

# %% [markdown]
# # Load domains
# merge nested and "almost" nested regions (regions overlapping a lot !)

# %%
_domains = pd.read_csv(
    "extrusion_domains/mG1s_MEGA_10kb_double_filtered.bedpe",
    sep="\t",
)
display(_domains.head())

# %%
mycmap = mpl.colors.LinearSegmentedColormap.from_list(
    name="myfall",
    colors=[ mpl.colors.to_hex(c) for c in plotting.PALETTES["fall"] ],
    N=2**16,
)
mycmap.set_bad('white',.5)
mycmap

# %%
_idid = bioframe.pair_by_distance(
    _anchors,
    min_sep=0,
    max_sep=200_000_000,  # should be enough ...
    suffixes=("1","2"),
    keep_order=True,
)

_idid = _idid.rename(columns={"bin_id1":"bin1_id", "bin_id2":"bin2_id", "bin_width1":"bin1_width", "bin_width2":"bin2_width"})

# %% [markdown]
# # Working on a Figure here
#
# 250kb (incl trans)
#  - region1 = ('chr6', 105000000, 155000000)
#  - region2 = ('chr7', 0, 56000000)
#
# 50kb
#  - ('chr6',125200000, 145200000)
#
# 10kb assembly on- and off-diagonal
#  - on diagonal #1: ('chr6', 129100000, 130500000)
#  - on diagonal #2: ('chr6', 136100000, 138200000)

# %%
# bws
# mycmap = mpl.colors.LinearSegmentedColormap.from_list(
#     name="myfall",
#     colors=[ mpl.colors.to_hex(c) for c in plotting.PALETTES["fall"] ],
#     N=2**16,
# )
# mycmap.set_bad('white',.5)
# mycmap
_chr6_len = bioframe.fetch_chromsizes("hg38")["chr6"]
# region1_250 = ('chr6', 105000000, _chr6_len)
# region2_250 = ('chr7', 0, 56000000)
# region1_50 = ('chr6', 125200000, 145200000)
region1_10 = ('chr6', 129100000, 130500000)
region2_10 = ('chr6', 136100000, 138200000)

# %%
_chr6_len = bioframe.fetch_chromsizes("hg38")["chr6"]
# region1_250 = ('chr6', 105000000+25_000_000, _chr6_len)
# region2_250 = ('chr7', 0, 56000000-35_000_000)
# # ...
# region1_50 = ('chr6', 125200000+1_500_000, 145200000-4_500_000)
# # ...
region1_10 = ('chr6', 129100000-30_000, 130500000+30_000)
region2_10 = ('chr6', 136100000-45_000, 138200000+45_000)
region1_10v = ('chr6', 129100000-30_000, 130500000-730_000+30_000)

# %%
from cooltools.lib import numutils

# %%
# def get_hm(
#     clr,
#     _idx_from,
#     _idx_to,
#     _jdx_from=None,
#     _jdx_to=None,
#     vmin=0.0002,
#     vmax=0.0125,
# ):
#     #
#     _jdx_from = _idx_from if _jdx_from is None else _jdx_from
#     _jdx_to = _idx_to if _jdx_to is None else _jdx_to
#     _mat = xr.DataArray(
#         clr.matrix()[_idx_from:_idx_to, _jdx_from:_jdx_to]
#     )
#     return tf.shade(
#         _mat,
#         cmap = mycmap,
#         # how = lambda x,y: np.power(x, 1/3.),
#         how = lambda x,y: np.log10(x),
#         span = (vmin, vmax),
#     ).to_pil(origin="upper")


# switch back to s
def get_hm(
    clr,
    _idx_from,
    _idx_to,
    _jdx_from=None,
    _jdx_to=None,
    vmin=0.0002,
    vmax=0.0125,
):
    #
    _jdx_from = _idx_from if _jdx_from is None else _jdx_from
    _jdx_to = _idx_to if _jdx_to is None else _jdx_to
    _mat = clr.matrix()[_idx_from:_idx_to, _jdx_from:_jdx_to]
    # need to NaN-out 2 diagonals ...
    if _idx_from == _jdx_from:
        for i in [-1,0,1]:
            _mat = numutils.fill_diag(_mat, np.nan, i)
        # ...
    _imshow_kwargs = dict(
        norm = LogNorm(vmin=vmin, vmax=vmax),
        cmap = mycmap,
        interpolation="nearest",
    )
    return _mat, _imshow_kwargs


# vlims_dict = {
#     "250": dict(vmin=0.000005, vmax=0.002),
#     "50": dict(vmin=0.0001, vmax=0.01),
#     "10_1": dict(vmin=0.0002, vmax=0.0125),
#     "10_2": dict(vmin=0.0001, vmax=0.0025),
# }

vlims_dict = {
    "250": dict(vmin=0.00001, vmax=0.003),
    "50": dict(vmin=0.00004, vmax=0.025),
    # "10_1": dict(vmin=0.00006, vmax=0.06),
    # "10_2": dict(vmin=0.00006, vmax=0.06),
    "10_1": dict(vmin=0.0001, vmax=0.01),
    "10_2": dict(vmin=0.0001, vmax=0.01),
}

# %%
# import matplotlib.pyplot as plt
import bbi
import matplotlib.lines as lines
from matplotlib.lines import Line2D
from matplotlib.patches import ConnectionPatch, Rectangle
from mpl_toolkits.axes_grid1 import Divider, Size
from mpl_toolkits.axes_grid1.inset_locator import BboxConnector

# manual colorbar example ...
# #
# cax = divider.append_axes("right", size=0.1, pad=0.05)
# plt.colorbar(
#     cm.ScalarMappable(norm=PowerNorm(1/3., vmin=vmin, vmax=vmax), cmap=mycmap),
#     cax=cax,
# )

# telo_clrs250.keys()
# ! ls -l ev_bigwig
# fig.add_axes((left, bottom, width, height))


# in a specific region, and exposing importnat plotting parameters
def rectangles_around_dots_ww(dots_bins_df, the_tile, loc="upper", lw=1, ec="cyan", fc="none", halo=30_000, ext_width=0):
    rectangle_kwargs = dict(lw=lw, ec=ec, fc=fc)
    # parse the tile
    _, tspan1, tspan2 = the_tile
    # select only visible "boxes" :
    _the_dots = dots_bins_df \
        .query("""(@tspan1[0] - @halo < bin1_id < @tspan1[1] + @halo) & \
                  (@tspan2[0] - @halo < bin2_id < @tspan2[1] + @halo) """) \
        .eval("""
                b1 = bin1_id - @tspan1[0] - @ext_width - 0.5
                b2 = bin2_id - @tspan2[0] - @ext_width - 0.5
                bin1_width = bin1_width + 2*@ext_width
                bin2_width = bin2_width + 2*@ext_width
            """)
    print(f"{len(_the_dots)} pixels are visible out of {len(dots_bins_df)} ...")
    for b1, b2, w1, w2 in _the_dots[["b1", "b2", "bin1_width", "bin2_width"]].itertuples(index=False):
        if loc == "upper":
            yield patches.Rectangle((b2, b1), w2+1, w1+1, **rectangle_kwargs)
        elif loc == "lower":
            yield patches.Rectangle((b1, b2), w1+1, w2+1, **rectangle_kwargs)
        else:
            raise ValueError("loc has to be uppper or lower")




def rectangles_at_anchors_vert(anchors_df, region_extent, ax, halo=30_000, ext_width=0, **span_kwargs):
    # rectangle_kwargs = dict(lw=lw, ec=ec, fc=fc)
    # parse the tile
    _bin_start, _bin_end = region_extent
    # select only visible "boxes" :
    _the_anchors = anchors_df \
        .query("""(@_bin_start - @halo < bin_id < @_bin_end + @halo)""") \
        .eval("""
                b = bin_id - @_bin_start - @ext_width - 0.5
                b_width = bin_width + 2*@ext_width
            """)
    print(f"{len(_the_anchors)} anchors are visible out of {len(anchors_df)} ...")
    for b, w in _the_anchors[["b", "b_width"]].itertuples(index=False):
        ax.axhspan(b, b+w, **span_kwargs)

# %%
cre_to_code = {
    'pls':6,
    'pels':5,
    'nels':5,
    'dels':4,
    'openk4':3,
    'ctcf':2,
    'justopen':1,
}

_cats = pd.CategoricalDtype(categories=list(range(6+1)), ordered=True)

cre_fnames = {
    "atac95_rest95" : "./bigbed/all_cres_encodestyle_pMunion_95atac_95rest.bed",  # control sorta, like before
    # "atac90_rest90" : "./bigbed/all_cres_encodestyle_pMunion_90atac_90rest.bed",
    # "atac70_rest70" : "./bigbed/all_cres_encodestyle_pMunion_70atac_70rest.bed",
    # "atac70_rest95" : "./bigbed/all_cres_encodestyle_pMunion_70atac_95rest.bed",
    # "atac70_rest90" : "./bigbed/all_cres_encodestyle_pMunion_70atac_90rest.bed",
    # "atac75_rest95" : "./bigbed/all_cres_encodestyle_pMunion_75atac_95rest.bed",
    # "atac75_rest90" : "./bigbed/all_cres_encodestyle_pMunion_75atac_90rest.bed",
}

_status_query = "(status_ == 0)|(status_ == 5)|(status_ == 4)|(status_ == 6)|(status_ == 7)"

binned_cre10_dfs = {}
for name, cre_fname in cre_fnames.items():
    df = pd.read_table(cre_fname, usecols=['chrom', 'start', 'end', 'name'])
    print(f"read {name=} with {len(df)} items ...")
    # # rename nels -> pels
    # df = df.replace({'name': {"nels": "pels"}})
    # sort by coordinate
    df = bioframe.sort_bedframe(df, view_df=hg38_arms)
    df["status"] = df["name"].map(cre_to_code)

    # now annotate bins with the anchors @10kb  ...
    _bin_cres = bioframe.overlap(clr_bins10, df)
    _bin_cres = _bin_cres.drop(columns=["chrom_","start_","end_"])
    _bin_cres["status_"] = _bin_cres["status_"].fillna(0).astype(int)
    # assign cCREs per bin according to the hierarchy ...
    binned_cres = _bin_cres.groupby(["chrom","start","end"], observed=True)["status_"].max().reset_index()
    binned_cres["status_"] = binned_cres["status_"].astype(_cats)
    # value_counts of annotated bins before gene assignment ...
    print("@10kb\n")
    display(binned_cres["status_"].value_counts().sort_index())
    print("\n")
    #
    binned_cre10_dfs[name] = binned_cres.astype({ "chrom" : str })


ticklabels = [
    "PLS",
    "pELS",
    "dELS",
    "opK4",
    "CTCF",
    "open",
    "none",
]


cre_cmap = {
    6: "darkred",  #"PLS",
    5: "red",  #"pELS",
    4: "orangered",  #"dELS",
    3: "pink",  #"opK4",
    2: "blue",  #"CTCF",
    1: "#ffee99",  #"open",
    # "none",
}
# # categroies are going to be 1,2,3,4,5,6
# # 0 - everything else ...
_none_color = "#D9E2EF"


_working_cres10 = binned_cre10_dfs['atac95_rest95']

# %%
_dfcre_reg1 = bioframe.select(_working_cres10, region1_10).reset_index(drop=True)
_dfcre_reg2 = bioframe.select(_working_cres10, region2_10).reset_index(drop=True)

_dfcre_reg1 = _dfcre_reg1.query("status_ > 0").reset_index(drop=True)
_dfcre_reg2 = _dfcre_reg2.query("status_ > 0").reset_index(drop=True)

# %%
bws_vlim['mG.atac']["vmin"] = 1
bws_vlim['mG.atac']["vmax"] = 100

bws_vlim['H3K27ac']["vmin"] = 10
bws_vlim['H3K27ac']["vmax"] = 1000

bws_vlim['H3K4me3']["vmin"] = 10
bws_vlim['H3K4me3']["vmax"] = 1000

# inactive genes ...
fwd_inact_args = fwd_args.copy()
fwd_inact_args["color"] = "lightgrey"

rev_inact_args = rev_args.copy()
rev_inact_args["color"] = "lightgrey"

# %%
margin = 0.2
matw = 1.333
cbarh = 0.07
cbarw = 0.7*matw


_region12_factor = (region2_10[2] - region2_10[1])/(region1_10[2] - region1_10[1])
_region1v_factor = (region1_10v[2] - region1_10v[1])/(region1_10[2] - region1_10[1])
# The first items are for padding and the second items are for the axes, sizes are in inch.
h = [
    Size.Fixed(margin), Size.Fixed(matw), Size.Fixed(0.2*margin), Size.Fixed(matw*_region12_factor),
]
# goes from bottom to the top ...
v = [
    Size.Fixed(margin), Size.Fixed(matw*0.075),
    Size.Fixed(0.2*margin), Size.Fixed(matw*0.13), Size.Fixed(matw*0.13), Size.Fixed(matw*0.13), Size.Fixed(matw*0.13),
    Size.Fixed(0.2*margin), Size.Fixed(matw*0.075),
    Size.Fixed(0.2*margin), Size.Fixed(matw*_region1v_factor), Size.Fixed(margin)
]

# set figsize based on the tiling provided ...
fig_width = sum(_h.fixed_size for _h in h)
fig_height = sum(_v.fixed_size for _v in v)
fig = plt.figure(
    figsize=(fig_width, fig_height),
    # facecolor='lightblue'
)
print(f"figure size {fig_width=} {fig_height=}")

divider = Divider(fig, (0, 0, 1, 1), h, v, aspect=False)
axs = {}
# # 10 kb region1 and region2 ....
axs["hmap_reg1_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1, ny=10))
axs["ids_reg1_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1, ny=8))
axs["atac_reg1_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1, ny=6))
axs["k27ac_reg1_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1, ny=5))
axs["k4me3_reg1_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1, ny=4))
axs["genes_reg1_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1, ny=3))
axs["cres_reg1_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1, ny=1))


axs["hmap_reg2_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3, ny=10))
axs["ids_reg2_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3, ny=8))
axs["atac_reg2_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3, ny=6))
axs["k27ac_reg2_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3, ny=5))
axs["k4me3_reg2_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3, ny=4))
axs["genes_reg2_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3, ny=3))
axs["cres_reg2_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3, ny=1))

# axs["hmap1_reg2_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3, ny=1+2))
# axs["track_reg2_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3, ny=3+2))
# axs["hmap2_reg2_bs10"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3, ny=5+2))


########################################
for k, ax in axs.items():
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)

_psample = "p5hR1R2"
clr10 = telo_clrs10[_psample]

# # heatmap and track for 250 kb
# _i1_250, _i10_250 = clr250.extent(region1_250)
# _i20_250, _i2_250 = clr250.extent(region2_250)
# _track_size_250 = _i2_250 - _i1_250
# mtrack1_250 = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_msample}.10kb.bw",region1_250[0],region1_250[1],region1_250[2], bins=_i10_250-_i1_250 ))
# mtrack2_250 = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_msample}.10kb.bw",region2_250[0],region2_250[1],region2_250[2], bins=_i2_250-_i20_250 ))
# ptrack1_250 = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_psample}.10kb.bw",region1_250[0],region1_250[1],region1_250[2], bins=_i10_250-_i1_250 ))
# ptrack2_250 = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_psample}.10kb.bw",region2_250[0],region2_250[1],region2_250[2], bins=_i2_250-_i20_250 ))

# # heatmap and track @ 50 kb ...
# _i1_50, _i2_50 = clr50.extent(region1_50)
# _track_size_50 = _i2_50 - _i1_50
# mtrack1_50 = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_msample}.10kb.bw",region1_50[0],region1_50[1],region1_50[2], bins=_i2_50-_i1_50 ))
# ptrack1_50 = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_psample}.10kb.bw",region1_50[0],region1_50[1],region1_50[2], bins=_i2_50-_i1_50 ))

# and region1 and 2 @ 10kb ...
_i1_10, _i2_10 = clr10.extent(region1_10)
_j1_10, _j2_10 = clr10.extent(region2_10)
_track_size1_10 = _i2_10 - _i1_10
_track_size2_10 = _j2_10 - _j1_10
# vertical side ...
_i1_10v, _i2_10v = clr10.extent(region1_10v)
# mtrack1_10 = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_msample}.10kb.bw",region1_10[0],region1_10[1],region1_10[2], bins=_i2_10-_i1_10 ))
# mtrack2_10 = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_msample}.10kb.bw",region2_10[0],region2_10[1],region2_10[2], bins=_j2_10-_j1_10 ))
# ptrack1_10 = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_psample}.10kb.bw",region1_10[0],region1_10[1],region1_10[2], bins=_i2_10-_i1_10 ))
# ptrack2_10 = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_psample}.10kb.bw",region2_10[0],region2_10[1],region2_10[2], bins=_j2_10-_j1_10 ))

# for ax_tag, ax in axs.items():
#     if "track" in ax_tag:
#         ax.axhline(0, color="grey", lw=0.5)
#         ax.set_ylim(-2, 2)

# 10 ...
hm, hmkwargs = get_hm(clr10, _i1_10v, _i2_10v, _i1_10, _i2_10, **vlims_dict["10_1"])
axs["hmap_reg1_bs10"].imshow(hm, **hmkwargs)
print(f"1st 510kb heatmap is {_track_size1_10} worth of pixels")

# and region2 @ 10kb ...
hm, hmkwargs = get_hm(clr10, _i1_10v, _i2_10v, _j1_10, _j2_10, **vlims_dict["10_2"])
axs["hmap_reg2_bs10"].imshow(hm, **hmkwargs)
print(f"2nd 10kb heatmap is {_track_size2_10} worth of pixels")



_track_factor=10_000
_bin_factor = 300/(region2_10[2] - region2_10[1])


#do tracks in a cycle ...
for _track, _bin_factor, _vlims, _ax1, _ax2, _color in zip(
    [bws['mG.atac'], bws['H3K27ac'], bws['H3K4me3']],
    [2*_bin_factor, 2*_bin_factor*0.75, 2*_bin_factor*0.666],
    [(0.03, 2), (0.001, 75), (0.001, 35)],
    [axs["atac_reg1_bs10"], axs["k27ac_reg1_bs10"], axs["k4me3_reg1_bs10"]],
    [axs["atac_reg2_bs10"], axs["k27ac_reg2_bs10"], axs["k4me3_reg2_bs10"]],
    ["black", "red", "darkred"],
):
    _bins1 = int( _bin_factor*( region1_10[2] - region1_10[1] ) )
    _bins2 = int( _bin_factor*( region2_10[2] - region2_10[1] ) )
    track1_10 = bbi.fetch(_track, region1_10[0], region1_10[1], region1_10[2], bins=_bins1, summary="mean", missing=0.0, oob=0.0)
    track2_10 = bbi.fetch(_track, region2_10[0], region2_10[1], region2_10[2], bins=_bins2, summary="mean", missing=0.0, oob=0.0)
    # _ax1.bar(
    #     x=np.arange(len(track1_10)),
    #     height=track1_10,
    #     width=1.2,
    #     log=False,
    #     color=_color,
    # )
    # _ax1.set_xlim(0, _bins1)
    # _ax1.set_ylim(*_vlims)
    # _ax2.bar(
    #     x=np.arange(len(track2_10)),
    #     height=track2_10,
    #     width=1.2,
    #     log=False,
    #     color=_color,
    # )
    # _ax2.set_xlim(0, _bins2)
    # _ax2.set_ylim(*_vlims)
    _ax1.fill_between(
        x=np.arange(len(track1_10)),
        y1=0,
        y2=track1_10,
        linewidth=0.5,
        # antialiased=True,
        # log=False,
        color=_color,
    )
    _ax1.set_xlim(0, _bins1)
    _ax1.set_ylim(*_vlims)
    _ax2.fill_between(
        x=np.arange(len(track2_10)),
        y1=0,
        y2=track2_10,
        linewidth=0.5,
        # antialiased=True,
        # log=False,
        color=_color,
    )
    _ax2.set_xlim(0, _bins2)
    _ax2.set_ylim(*_vlims)

##############################################
# add ID-ID ...
##############################################

# ...
_big_boxes_kwargs = dict(halo=100, lw=0.5, ec='black')
# ...
ax = axs["hmap_reg1_bs10"]
axid = axs["ids_reg1_bs10"]
axid.set_xlim(0-0.5,_track_size1_10-0.5)
# axs["hmap_reg2_bs10"]
# draw boxes around clustered pixels ...
for box in rectangles_around_dots_ww(
    _idid,
    (region1_10[0], (_i1_10v, _i2_10v), (_i1_10, _i2_10)),
    ext_width=0,
    **_big_boxes_kwargs,
):
    ax.add_patch(box)
    x0, y0, dx, dy = box.get_bbox().bounds
    axid.axvspan(x0, x0+dx, facecolor='black', alpha=1)


ax = axs["hmap_reg2_bs10"]
axid = axs["ids_reg2_bs10"]
axid.set_xlim(0-0.5,_track_size2_10-0.5)
# draw boxes around clustered pixels ...
for box in rectangles_around_dots_ww(
    _idid,
    (region1_10[0], (_i1_10v, _i2_10v), (_j1_10, _j2_10)),
    ext_width=0,
    **_big_boxes_kwargs,
):
    ax.add_patch(box)
    x0, y0, dx, dy = box.get_bbox().bounds
    axid.axvspan(x0, x0+dx, facecolor='black', alpha=1)

# ########################
# Plots genes !
# region 1
_start, _end = region1_10[1], region1_10[2]
# _start, _end = region1_10[1]-200_000, region1_10[2]+200_000
_ax = axs["genes_reg1_bs10"]
# _gfs_fwd = GraphicRecord(
#     sequence_length=(_end-_start+1),
#     features=[
#         GraphicFeature(_row.start, _row.end, **fwd_inact_args) for _row in \
#         bioframe.merge(
#             bioframe.expand(bioframe.select(_fwd_inact, region1_10), pad=8_000),
#             min_dist = 20_000,
#         ).itertuples(index=False)
#     ],
# )
_gfs_rev = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **rev_inact_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_rev_inact, region1_10), pad=8_000),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_fwd.plot(ax=_ax, x_lim=(_start, _end), level_offset=-0.45, **plotargs)
_gfs_rev.plot(ax=_ax, x_lim=(_start, _end), level_offset=0.45, **plotargs)
# ...
_gfs_fwd = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **fwd_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_fwd_act, region1_10), pad=8_000),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_rev = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **rev_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_rev_act, region1_10), pad=8_000),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_fwd.plot(ax=_ax, x_lim=(_start, _end), level_offset=-0.45, **plotargs)
_gfs_rev.plot(ax=_ax, x_lim=(_start, _end), level_offset=0.45, **plotargs)
_ax.set_ylim(-1,1)
_ax.set_axis_on()



# ########################
# Plots genes !
# region 2
_start, _end = region2_10[1], region2_10[2]
_ax = axs["genes_reg2_bs10"]
_gfs_fwd = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **fwd_inact_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_fwd_inact, region2_10), pad=8_000),
            min_dist=20_000,
        ).itertuples(index=False)
    ],
)
_gfs_rev = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **rev_inact_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_rev_inact, region2_10), pad=8_000),
            min_dist=20_000,
        ).itertuples(index=False)
    ],
)
_gfs_fwd.plot(ax=_ax, x_lim=(_start, _end), level_offset=-0.45, **plotargs)
_gfs_rev.plot(ax=_ax, x_lim=(_start, _end), level_offset=0.45, **plotargs)
# ...
_gfs_fwd = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **fwd_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_fwd_act, region2_10), pad=8_000),
            min_dist=20_000,
        ).itertuples(index=False)
    ],
)
_gfs_rev = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **rev_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_rev_act, region2_10), pad=8_000),
            min_dist=20_000,
        ).itertuples(index=False)
    ],
)
_gfs_fwd.plot(ax=_ax, x_lim=(_start, _end), level_offset=-0.45, **plotargs)
_gfs_rev.plot(ax=_ax, x_lim=(_start, _end), level_offset=0.45, **plotargs)

_ax.set_ylim(-1,1)
_ax.set_axis_on()


# axs["cres_reg1_bs10"]
# axs["cres_reg2_bs10"]
_reg1_start = region1_10[1]
_reg2_start = region2_10[1]
_reg1_len = region1_10[2] - _reg1_start
_reg2_len = region2_10[2] - _reg2_start

# draw CREs here ...
for _chrom, _start, _end, _status_ in _dfcre_reg1.itertuples(index=False):
    axs["cres_reg1_bs10"].axvspan(
        _start-_reg1_start,
        _end-_reg1_start,
        facecolor=cre_cmap[_status_],
        lw=0.0,
        ec=None,
    )
# draw CREs here ...
for _chrom, _start, _end, _status_ in _dfcre_reg2.itertuples(index=False):
    axs["cres_reg2_bs10"].axvspan(
        _start-_reg2_start,
        _end-_reg2_start,
        facecolor=cre_cmap[_status_],
        lw=0.0,
        ec=None,
    )

axs["cres_reg1_bs10"].set_xlim(0,_reg1_len)
axs["cres_reg2_bs10"].set_xlim(0,_reg2_len)

axs["cres_reg1_bs10"].set_facecolor(_none_color)
axs["cres_reg2_bs10"].set_facecolor(_none_color)


plt.savefig("Fig2B.pdf", dpi=300)

# %% [markdown]
# # Figure 5 heatmap with tracks and annotations ...

# %%
# switch back to s
def get_hm_double(
    clr_up,
    clr_down,
    _idx_from,
    _idx_to,
    _jdx_from=None,
    _jdx_to=None,
    vmin=0.0002,
    vmax=0.0125,
):
    #
    _jdx_from = _idx_from if _jdx_from is None else _jdx_from
    _jdx_to = _idx_to if _jdx_to is None else _jdx_to
    _mat_up = clr_up.matrix()[_idx_from:_idx_to, _jdx_from:_jdx_to]
    _mat_down = clr_down.matrix()[_idx_from:_idx_to, _jdx_from:_jdx_to]
    _mat = np.tril(_mat_down)+np.triu(_mat_up)
    # need to NaN-out 2 diagonals ...
    if _idx_from == _jdx_from:
        for i in [-1,0,1]:
            _mat = numutils.fill_diag(_mat, np.nan, i)
        # ...
    _imshow_kwargs = dict(
        norm = LogNorm(vmin=vmin, vmax=vmax),
        cmap = mycmap,
        interpolation="nearest",
    )
    return _mat, _imshow_kwargs

# %%
_region5 = (
    'chr7',
    20_500_000,
    28_500_000,
)

_region5_zoom = (
    'chr7',
    25_700_000,
    28_000_000,
)



_msample = "m5hR1R2"
clrM = telo_clrs25[_msample]

_psample = "p5hR1R2"
clrP = telo_clrs25[_psample]

clrM_zoom = telo_clrs10[_msample]
clrP_zoom = telo_clrs10[_psample]

# %%
# _region5



# in a specific region, and exposing importnat plotting parameters
def draw_ondiag_domains(bed_df, the_tile, lw=1, ec="cyan", fc="none", halo=30_000, ext_width=0):
    rectangle_kwargs = dict(lw=lw, ec=ec, fc=fc)
    # parse the tile
    _, tspan1, tspan2 = the_tile
    # select only visible "boxes" :
    _the_dots = bed_df \
        .query("""(@tspan1[0] - @halo < bin1_id < @tspan1[1] + @halo) & \
                  (@tspan2[0] - @halo < bin2_id < @tspan2[1] + @halo) """) \
        .eval("""
                b1 = bin1_id - @tspan1[0] - @ext_width
                b2 = bin2_id - @tspan2[0] - @ext_width
            """)
    for b1, b2 in _the_dots[["b1", "b2"]].itertuples(index=False):
        yield patches.Rectangle((b1, b1), b2-b1+1, b2-b1+1, **rectangle_kwargs)




# in a specific region, and exposing importnat plotting parameters
def rectangles_at_anchors(anchors_df, region_extent, ax, halo=30_000, ext_width=0, **span_kwargs):
    # rectangle_kwargs = dict(lw=lw, ec=ec, fc=fc)
    # parse the tile
    _bin_start, _bin_end = region_extent
    # select only visible "boxes" :
    _the_anchors = anchors_df \
        .query("""(@_bin_start - @halo < bin_id < @_bin_end + @halo)""") \
        .eval("""
                b = bin_id - @_bin_start - @ext_width - 0.5
                b_width = bin_width + 2*@ext_width
            """)
    print(f"{len(_the_anchors)} anchors are visible out of {len(anchors_df)} ...")
    for b, w in _the_anchors[["b", "b_width"]].itertuples(index=False):
        ax.axvspan(b, b+w, **span_kwargs)




# domains within selected region - turn it back to bedpe ...
_domains_region = \
_domains.eval("""
    chrom1 = chrom
    chrom2 = chrom
    start1 = start
    end1 = start + 10_000
    start2 = end - 10_000
    end2 = end
""")[['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']]#, 'n_intervals']]

# select domains in the region ...
_domains_region = bioframe.select(
    bioframe.select(_domains_region, _region5, cols=("chrom1","start1","end1")),
    _region5, cols=("chrom2","start2","end2"),
).reset_index(drop=True)
_domains_region["bin1_id"] = _domains_region[["chrom1","start1","end1"]].apply(clrM_zoom.offset,axis=1,result_type="expand")
_domains_region["bin1_width"] = _domains_region[["chrom1","start1","end1"]].apply(clrM_zoom.extent,axis=1,result_type="expand").apply(np.diff,axis=1,result_type="expand")[0]
_domains_region["bin2_id"] = _domains_region[["chrom2","start2","end2"]].apply(clrM_zoom.offset,axis=1,result_type="expand")
_domains_region["bin2_width"] = _domains_region[["chrom2","start2","end2"]].apply(clrM_zoom.extent,axis=1,result_type="expand").apply(np.diff,axis=1,result_type="expand")[0]

# %%
# and region1 and 2 @ 10kb ...
_i1_5, _i2_5 = clrM.extent(_region5)
_i1_5z, _i2_5z = clrM_zoom.extent(_region5_zoom)

_i1_5z_inset, _i2_5z_inset = clrM.extent(_region5_zoom)
_inset_size = _i2_5z_inset - _i1_5z_inset
_i1_5z_inset -= _i1_5

patch_kwargs = dict(color="black", fc="none", lw=0.5)

margin = 0.2
matw = 1.333
cbarh = 0.07
cbarw = 0.7*matw
mat_to_mcd = 0.125*margin
chrom_to_mat = 0.3*margin

# The first items are for padding and the second items are for the axes, sizes are in inch.
h = [
    Size.Fixed(margin), Size.Fixed(matw*0.1), Size.Fixed(chrom_to_mat), Size.Fixed(matw),  # 25kb hic
    Size.Fixed(mat_to_mcd), Size.Fixed(cbarh),  # vertical MCDs ...
    Size.Fixed(margin), Size.Fixed(matw),  # 10kb zoom in
    Size.Fixed(mat_to_mcd), Size.Fixed(cbarh),  # MCDs and genes ...
    Size.Fixed(margin)
]
# goes from bottom to the top ...
v = [
    Size.Fixed(margin),
    Size.Fixed(cbarh), Size.Fixed(0.2*margin),
    Size.Fixed(matw*0.11), Size.Fixed(matw*0.075),  # genes, 27ac
    Size.Fixed(matw*0.1), Size.Fixed(0.2*margin), Size.Fixed(cbarh),  # EVs, MCDs
    Size.Fixed(mat_to_mcd), Size.Fixed(matw),
    Size.Fixed(margin)
]

# set figsize based on the tiling provided ...
fig_width = sum(_h.fixed_size for _h in h)
fig_height = sum(_v.fixed_size for _v in v)
fig = plt.figure(
    figsize=(fig_width, fig_height),
    # facecolor='lightblue'
)
print(f"figure size {fig_width=} {fig_height=}")

divider = Divider(fig, (0, 0, 1, 1), h, v, aspect=False)




axs = {}
# # 10 kb region1 and region2 ....
axs["chrom"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1, ny=7+2))

axs["hmap"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1+2, ny=7+2))
axs["hmap_zoom"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+4, ny=7+2))

axs["genes"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1+2, ny=1+2))
axs["k27ac"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1+2, ny=2+2))
axs["evs"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1+2, ny=3+2))
axs["mcd"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1+2, ny=5+2))
axs["mcd_vert"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+2, ny=7+2))

axs["genes_zoom"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+4, ny=1+2))
axs["k27ac_zoom"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+4, ny=2+2))
axs["evs_zoom"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+4, ny=3+2))
axs["mcd_zoom"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+4, ny=5+2))
axs["mcd_zoom_vert"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=5+4, ny=7+2))

mtrack = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_msample}.{binsize25//1_000}kb.bw",_region5[0],_region5[1],_region5[2], bins=_i2_5-_i1_5 ))
mtrack_zoom = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_msample}.{binsize10//1_000}kb.bw",_region5_zoom[0],_region5_zoom[1],_region5_zoom[2], bins=_i2_5z-_i1_5z ))
ptrack = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_psample}.{binsize25//1_000}kb.bw",_region5[0],_region5[1],_region5[2], bins=_i2_5-_i1_5 ))
ptrack_zoom = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_psample}.{binsize10//1_000}kb.bw",_region5_zoom[0],_region5_zoom[1],_region5_zoom[2], bins=_i2_5z-_i1_5z ))


cbar = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1+2, ny=1))
cbar_zoom = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+4, ny=1))


_mev_color = "tab:blue"
_pev_color = "tab:red"


########################################
for k, ax in axs.items():
    # ax.xaxis.set_visible(False)
    # ax.yaxis.set_visible(True)
    ax.set_xticks([])
    ax.set_yticks([])



# plot EV tracks ...
axs["evs"].axhline(0, lw=0.5, color="grey")
axs["evs"].plot(mtrack, lw=0.7, color=_mev_color)
axs["evs"].plot(ptrack, lw=0.7, color=_pev_color)
axs["evs"].set_xlim(0, len(mtrack))


axs["evs_zoom"].axhline(0, lw=0.5, color="grey")
axs["evs_zoom"].plot(mtrack_zoom, lw=0.7, color=_mev_color)
axs["evs_zoom"].plot(ptrack_zoom, lw=0.7, color=_pev_color)
axs["evs_zoom"].set_xlim(0, len(mtrack_zoom))


hm, hmkwargs = get_hm_double(clrM, clrP, _i1_5, _i2_5, **vlims_dict["50"])
hmkwargs["interpolation"] = "antialiased"
hmkwargs["interpolation_stage"] = "rgba"
axs["hmap"].imshow(hm, **hmkwargs)

_rec = Rectangle(
    (_i1_5z_inset, _i1_5z_inset),
    _inset_size, _inset_size,
    **patch_kwargs,
)
# draw those box and lines ...
axs["hmap"].add_patch(_rec)


#################################
# chrom schematics on both axes ...
ax = axs["chrom"]
_7pl = arms_dict["chr7_p"]
_7ql = arms_dict["chr7_q"]
_regions_highlight = [("p", _7pl-20, _7pl-29, "dimgray"), ]
_ww = 0.1*(_7pl+_7ql)
_7, _7hs = get_chrom_path_wpathes(
    (0, 0),  # position of the centromere ...
    parm=_7pl,  # p arm length
    qarm=_7ql,  # q arm length
    width=_ww,  # width
    color="lightsteelblue",
    patches=_regions_highlight,
)
ax.set_axis_off()
ax.add_artist(_7)
for _h in _7hs:
    ax.add_artist(_h)
ax.set_xlim(-1.0*_ww, 1.0*_ww)
ax.set_ylim(-(_7ql)-(0.11+0.1)*_ww, (_7pl)+(0.11+0.1)*_ww)
##################################################
ax_chrom = axs["chrom"]
ax = axs["hmap"]
con = ConnectionPatch(
    xyA=(0.5*_ww, _7pl-20),
    coordsA=ax_chrom.transData,
    xyB=(0.0, 1.0),
    coordsB=ax.transAxes,
    **patch_kwargs,
)
ax.add_artist(con)
con = ConnectionPatch(
    xyA=(0.5*_ww, _7pl-29),
    coordsA=ax_chrom.transData,
    xyB=(0.0, 0.0),
    coordsB=ax.transAxes,
    **patch_kwargs,
)
ax.add_artist(con)
# ##################################################

# plot MCDs ...
mcd_kwargs = dict(color="black", alpha=1,ec=None)

# doing that using clr.offset and clr.extent functionality:
_anchors["bin_id"] = _anchors[['chrom', 'peak_start', 'peak_end']].apply(clrM.offset, axis=1, result_type="expand")
_anchors["bin_width"] = _anchors[['chrom', 'peak_start', 'peak_end']] \
    .apply(clrM.extent, axis=1, result_type="expand") \
    .apply(np.diff, axis=1, result_type="expand")[0]
rectangles_at_anchors(_anchors, clrM.extent(_region5), axs["mcd"], ext_width=-0.5, **mcd_kwargs)
axs["mcd"].set_xlim(0, _i2_5-_i1_5)

# vertical ones ...
rectangles_at_anchors_vert(_anchors, clrM.extent(_region5), axs["mcd_vert"], ext_width=-0.5, **mcd_kwargs)
axs["mcd_vert"].set_ylim(0, _i2_5-_i1_5)
axs["mcd_vert"].invert_yaxis()

# doing that using clr.offset and clr.extent functionality:
_anchors["bin_id"] = _anchors[['chrom', 'peak_start', 'peak_end']].apply(clrM_zoom.offset, axis=1, result_type="expand")
_anchors["bin_width"] = _anchors[['chrom', 'peak_start', 'peak_end']] \
    .apply(clrM_zoom.extent, axis=1, result_type="expand") \
    .apply(np.diff, axis=1, result_type="expand")[0]
rectangles_at_anchors(_anchors, clrM_zoom.extent(_region5_zoom), axs["mcd_zoom"], ext_width=-0.5, **mcd_kwargs)
axs["mcd_zoom"].set_xlim(0, _i2_5z-_i1_5z)

# vertical ones ...
rectangles_at_anchors_vert(_anchors, clrM_zoom.extent(_region5_zoom), axs["mcd_zoom_vert"], ext_width=-0.5, **mcd_kwargs)
axs["mcd_zoom_vert"].set_ylim(0, _i2_5z-_i1_5z)
axs["mcd_zoom_vert"].invert_yaxis()


# ########################
# Plots genes !
# region 1
_start, _end = _region5[1], _region5[2]
_ax = axs["genes"]
_gfs_fwd = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **fwd_inact_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_fwd, _region5), pad=10_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_rev = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **rev_inact_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_rev, _region5), pad=10_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_fwd.plot(ax=_ax, x_lim=(_start, _end), level_offset=-0.45, **plotargs)
_gfs_rev.plot(ax=_ax, x_lim=(_start, _end), level_offset=0.45, **plotargs)
# ...
_gfs_fwd = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **fwd_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_fwd_act, _region5), pad=10_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_rev = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **rev_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_rev_act, _region5), pad=10_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_fwd.plot(ax=_ax, x_lim=(_start, _end), level_offset=-0.45, **plotargs)
_gfs_rev.plot(ax=_ax, x_lim=(_start, _end), level_offset=0.45, **plotargs)
# ...
_ax.set_ylim(-1,1)
_ax.set_axis_on()






_track_factor=10_000
_bin_factor = 500/(_region5_zoom[2] - _region5_zoom[1])
#do tracks in a cycle ...
_track, _bin_factor, _vlims, _ax1, _ax2, _color = (
    bws['H3K27ac'],
    2*_bin_factor*0.75,
    (0.001, 75),
    axs["k27ac"],
    axs["k27ac_zoom"],
    "red",
)

_bins1 = int( _bin_factor*( _region5[2] - _region5[1] ) )
_bins2 = int( _bin_factor*( _region5_zoom[2] - _region5_zoom[1] ) )
track = bbi.fetch(_track, _region5[0], _region5[1], _region5[2], bins=_bins1, summary="mean", missing=0.0, oob=0.0)
track_zoom = bbi.fetch(_track, _region5_zoom[0], _region5_zoom[1], _region5_zoom[2], bins=_bins2, summary="mean", missing=0.0, oob=0.0)
_ax1.fill_between(
    x=np.arange(len(track)),
    y1=0,
    y2=track,
    linewidth=0.5,
    # antialiased=True,
    # log=False,
    color=_color,
)
_ax1.set_xlim(0, _bins1)
_ax1.set_ylim(*_vlims)
_ax2.fill_between(
    x=np.arange(len(track_zoom)),
    y1=0,
    y2=track_zoom,
    linewidth=0.5,
    # antialiased=True,
    # log=False,
    color=_color,
)
_ax2.set_xlim(0, _bins2)
_ax2.set_ylim(*_vlims)






hm, hmkwargs = get_hm_double(clrM_zoom, clrP_zoom, _i1_5z, _i2_5z, **vlims_dict["10_1"])
hmkwargs["interpolation"] = "antialiased"
hmkwargs["interpolation_stage"] = "rgba"
axs["hmap_zoom"].imshow(hm, **hmkwargs)

# draw domains on the zoomed in heatmap ...
_big_boxes_kwargs = dict(lw=1., ec="green", fc="none", halo=100, ext_width=2)
for box in draw_ondiag_domains(_domains_region, ("...", (_i1_5z, _i2_5z), (_i1_5z, _i2_5z)), **_big_boxes_kwargs):
    axs["hmap_zoom"].add_patch(box)


# ########################
# Plots genes !
# region 1
_start, _end = _region5_zoom[1], _region5_zoom[2]
_ax = axs["genes_zoom"]
_gfs_fwd = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **fwd_inact_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_fwd, _region5_zoom), pad=8_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_rev = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **rev_inact_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_rev, _region5_zoom), pad=8_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_fwd.plot(ax=_ax, x_lim=(_start, _end), level_offset=-0.45, **plotargs)
_gfs_rev.plot(ax=_ax, x_lim=(_start, _end), level_offset=0.45, **plotargs)
# ...
_gfs_fwd = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **fwd_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_fwd_act, _region5_zoom), pad=8_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_rev = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **rev_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_rev_act, _region5_zoom), pad=8_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_fwd.plot(ax=_ax, x_lim=(_start, _end), level_offset=-0.45, **plotargs)
_gfs_rev.plot(ax=_ax, x_lim=(_start, _end), level_offset=0.45, **plotargs)
_ax.set_ylim(-1,1)
_ax.set_axis_on()



axs["genes"].axis("off")
axs["k27ac"].axis("off")
axs["evs"].axis("off")

axs["genes_zoom"].axis("off")
axs["k27ac_zoom"].axis("off")
axs["evs_zoom"].axis("off")








# it's 25 actually - but whatever
_vmin, _vmax = vlims_dict["50"]["vmin"], vlims_dict["50"]["vmax"]
plt.colorbar(
    # cm.ScalarMappable(norm=PowerNorm(1/3., vmin=_vmin, vmax=_vmax), cmap=mycmap),
    cm.ScalarMappable(norm=LogNorm(vmin=_vmin, vmax=_vmax), cmap=mycmap),
    cax=cbar,
    orientation="horizontal",
)
cbar.xaxis.set_visible(True)
_ticks_power = range(
    np.ceil(np.log10(_vmin)).astype(int),
    np.floor(np.log10(_vmax)).astype(int)+1,
)
cbar.set_xticks([np.power(10.,_p) for _p in _ticks_power])
cbar.set_xticklabels(['$\mathdefault{10^{%i}}$' % l for l in _ticks_power])
cbar.xaxis.set_tick_params(labelsize=6, pad=0.1, length=2)
cbar.minorticks_off()


# it's 25 actually - but whatever
_vmin, _vmax = vlims_dict["10_1"]["vmin"], vlims_dict["10_1"]["vmax"]
plt.colorbar(
    # cm.ScalarMappable(norm=PowerNorm(1/3., vmin=_vmin, vmax=_vmax), cmap=mycmap),
    cm.ScalarMappable(norm=LogNorm(vmin=_vmin, vmax=_vmax), cmap=mycmap),
    cax=cbar_zoom,
    orientation="horizontal",
)
cbar_zoom.xaxis.set_visible(True)
_ticks_power = range(
    np.ceil(np.log10(_vmin)).astype(int),
    np.floor(np.log10(_vmax)).astype(int)+1,
)
cbar_zoom.set_xticks([np.power(10.,_p) for _p in _ticks_power])
cbar_zoom.set_xticklabels(['$\mathdefault{10^{%i}}$' % l for l in _ticks_power])
cbar_zoom.xaxis.set_tick_params(labelsize=6, pad=0.1, length=2)
cbar_zoom.minorticks_off()



plt.savefig("Fig5J.svg", dpi=300)

# %%
# # domains within selected region - turn it back to bedpe ...
# _domains_region = \
# _domains.eval("""
#     chrom1 = chrom
#     chrom2 = chrom
#     start1 = start
#     end1 = start + 10_000
#     start2 = end - 10_000
#     end2 = end
# """)[['chrom1', 'start1', 'end1', 'chrom2', 'start2', 'end2']]#, 'n_intervals']]

# # select domains in the region ...
# _domains_region = bioframe.select(
#     bioframe.select(_domains_region, _region5, cols=("chrom1","start1","end1")),
#     _region5, cols=("chrom2","start2","end2"),
# ).reset_index(drop=True)
# _domains_region["bin1_id"] = _domains_region[["chrom1","start1","end1"]].apply(clrM.offset,axis=1,result_type="expand")
# _domains_region["bin1_width"] = _domains_region[["chrom1","start1","end1"]].apply(clrM.extent,axis=1,result_type="expand").apply(np.diff,axis=1,result_type="expand")[0]
# _domains_region["bin2_id"] = _domains_region[["chrom2","start2","end2"]].apply(clrM.offset,axis=1,result_type="expand")
# _domains_region["bin2_width"] = _domains_region[["chrom2","start2","end2"]].apply(clrM.extent,axis=1,result_type="expand").apply(np.diff,axis=1,result_type="expand")[0]

# hm, hmkwargs = get_hm_double(clrM, clrP, _i1_5, _i2_5, **vlims_dict["50"])
# hmkwargs["interpolation"] = "gaussian"
# hmkwargs["interpolation_stage"] = "rgba"
# plt.imshow(hm, **hmkwargs)
# ax = plt.gca()
# # draw domains on the zoomed in heatmap ...
# _big_boxes_kwargs = dict(lw=1., ec="green", fc="none", halo=100, ext_width=1)
# for box in draw_ondiag_domains(_domains_region, ("...", (_i1_5, _i2_5), (_i1_5, _i2_5)), **_big_boxes_kwargs):
#     ax.add_patch(box)

# %%
_region5k = (
    'chr8',
    29_380_000,
    40_000_000,
)
_region5k_zoom_A = (
    'chr8',
    29_500_000,
    31_400_000,
)
_region5k_zoom_B = (
    'chr8',
    36_490_000,
    39_830_000,
)

fracAB = (_region5k_zoom_B[2] - _region5k_zoom_B[1]) / (_region5k_zoom_A[2] - _region5k_zoom_A[1])

_msample = "m5hR1R2"
clrM = telo_clrs25[_msample]

_psample = "p5hR1R2"
clrP = telo_clrs25[_psample]

clrM_zoom = telo_clrs10[_msample]
clrP_zoom = telo_clrs10[_psample]

# %%
# and region1 and 2 @ 10kb ...
_i1, _i2 = clrM.extent(_region5k)

_i1_A, _i2_A = clrM_zoom.extent(_region5k_zoom_A)
_i1_B, _i2_B = clrM_zoom.extent(_region5k_zoom_B)

_i1_A_inset, _i2_A_inset = clrM.extent(_region5k_zoom_A)
_i1_B_inset, _i2_B_inset = clrM.extent(_region5k_zoom_B)
# ...
_i1_A_inset -= _i1
_i2_A_inset -= _i1
# ...
_i1_B_inset -= _i1
_i2_B_inset -= _i1
# ...
size_A = _i2_A_inset-_i1_A_inset
size_B = _i2_B_inset-_i1_B_inset

patch_kwargs = dict(color="black", fc="none", lw=0.5)

margin = 0.2
matw = 1.333
cbarh = 0.07
cbarw = 0.7*matw
mat_to_mcd = 0.125*margin
chrom_to_mat = 0.3*margin
zoom_mat = 0.475*matw


_mev_color = "tab:blue"
_pev_color = "tab:red"

# The first items are for padding and the second items are for the axes, sizes are in inch.
h = [
    # 0,1,2,3
    Size.Fixed(margin), Size.Fixed(matw*0.1), Size.Fixed(chrom_to_mat), Size.Fixed(matw),  # 25kb hic
    Size.Fixed(mat_to_mcd), Size.Fixed(cbarh),  # 4,5
    # 6
    Size.Fixed(margin),
    # split matrix into 4 pieces for zoomin
    # 7
    Size.Fixed(zoom_mat*fracAB),
    Size.Fixed(mat_to_mcd), Size.Fixed(cbarh), Size.Fixed(margin) # vert MCDs
]
# goes from bottom to the top ...
v = [
    # 0
    Size.Fixed(margin),
    Size.Fixed(cbarh), Size.Fixed(0.2*margin),
    # 1,2
    Size.Fixed(matw*0.11), Size.Fixed(matw*0.075),  # genes, 27ac
    # 3,4,5
    Size.Fixed(matw*0.1), Size.Fixed(0.2*margin), Size.Fixed(cbarh),  # EVs, MCDs
    # 6
    Size.Fixed(mat_to_mcd),
    # 7,8,9
    # split matrix into 4 quadrants ...
    Size.Fixed(zoom_mat), Size.Fixed(0.05*matw), Size.Fixed(zoom_mat),
    Size.Fixed(margin),
]

# set figsize based on the tiling provided ...
fig_width = sum(_h.fixed_size for _h in h)
fig_height = sum(_v.fixed_size for _v in v)
fig = plt.figure(
    figsize=(fig_width, fig_height),
    # facecolor='lightblue'
)
print(f"figure size {fig_width=} {fig_height=}")

divider = Divider(fig, (0, 0, 1, 1), h, v, aspect=False)


axs = {}
# # 10 kb region1 and region2 ....
axs["chrom"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1, ny=7+2, ny1=10+2))
axs["hmap"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1+2, ny=7+2, ny1=10+2))

axs["hmap_zoom_up"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+4, ny=9+2))
axs["hmap_zoom_bot"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+4, ny=7+2))

axs["mcd_zoom_up"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=5+4, ny=9+2))
axs["mcd_zoom_bot"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=5+4, ny=7+2))


# axs["hmap_zoom_C"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+4, ny=7+2))
# axs["hmap_zoom_D"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=5+4, ny=7+2))

axs["genes"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1+2, ny=1+2))
axs["k27ac"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1+2, ny=2+2))
axs["evs"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1+2, ny=3+2))
axs["mcd"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1+2, ny=5+2))
axs["mcd_vert"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+2, ny=7+2, ny1=10+2))

axs["genes_zoom"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+4, ny=1+2))
axs["k27ac_zoom"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+4, ny=2+2))
axs["evs_zoom"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+4, ny=3+2))
axs["mcd_zoom"] = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+4, ny=5+2))

mtrack = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_msample}.{binsize25//1_000}kb.bw",_region5k[0],_region5k[1],_region5k[2], bins=_i2-_i1 ))
ptrack = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_psample}.{binsize25//1_000}kb.bw",_region5k[0],_region5k[1],_region5k[2], bins=_i2-_i1 ))


cbar = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=1+2, ny=1))
cbar_zoom = fig.add_axes(divider.get_position(), axes_locator=divider.new_locator(nx=3+4, ny=1))


# plot EV tracks ...
axs["evs"].axhline(0, lw=0.5, color="grey")
axs["evs"].plot(mtrack, lw=0.7, color=_mev_color)
axs["evs"].plot(ptrack, lw=0.7, color=_pev_color)
axs["evs"].set_xlim(0, len(mtrack))


# _region5k_zoom_B
mtrack_zoom = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_msample}.{binsize10//1_000}kb.bw",_region5k_zoom_B[0],_region5k_zoom_B[1],_region5k_zoom_B[2], bins=_i2_B - _i1_B ))
ptrack_zoom = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_psample}.{binsize10//1_000}kb.bw",_region5k_zoom_B[0],_region5k_zoom_B[1],_region5k_zoom_B[2], bins=_i2_B - _i1_B ))


axs["evs_zoom"].axhline(0, lw=0.5, color="grey")
axs["evs_zoom"].plot(mtrack_zoom, lw=0.7, color=_mev_color)
axs["evs_zoom"].plot(ptrack_zoom, lw=0.7, color=_pev_color)
axs["evs_zoom"].set_xlim(0, len(mtrack_zoom))



#################################
# chrom schematics on both axes ...
ax = axs["chrom"]
_8pl = arms_dict["chr8_p"]
_8ql = arms_dict["chr8_q"]
_regions_highlight = [("p", _8pl-26, _8pl-38, "dimgray"), ]
_ww = 0.1*(_8pl+_8ql)
_8, _8hs = get_chrom_path_wpathes(
    (0, 0),  # position of the centromere ...
    parm=_8pl,  # p arm length
    qarm=_8ql,  # q arm length
    width=_ww,  # width
    color="lightsteelblue",
    patches=_regions_highlight,
)
ax.set_axis_off()
ax.add_artist(_8)
for _h in _8hs:
    ax.add_artist(_h)
ax.set_xlim(-1.0*_ww, 1.0*_ww)
ax.set_ylim(-(_8ql)-(0.11+0.1)*_ww, (_8pl)+(0.11+0.1)*_ww)
##################################################
ax_chrom = axs["chrom"]
ax = axs["hmap"]
con = ConnectionPatch(
    xyA=(0.5*_ww, _8pl-26),
    coordsA=ax_chrom.transData,
    xyB=(0.0, 1.0),
    coordsB=ax.transAxes,
    **patch_kwargs,
)
ax.add_artist(con)
con = ConnectionPatch(
    xyA=(0.5*_ww, _8pl-38),
    coordsA=ax_chrom.transData,
    xyB=(0.0, 0.0),
    coordsB=ax.transAxes,
    **patch_kwargs,
)
ax.add_artist(con)
# ##################################################


# # _region5k_zoom_A
# mtrack_zoom = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_msample}.{binsize10//1_000}kb.bw",_region5k_zoom_B[0],_region5k_zoom_B[1],_region5k_zoom_B[2], bins=_i2_5z-_i1_5z ))
# ptrack_zoom = np.nan_to_num(bbi.fetch(f"ev_bigwig/{_psample}.{binsize10//1_000}kb.bw",_region5k_zoom_B[0],_region5k_zoom_B[1],_region5k_zoom_B[2], bins=_i2_5z-_i1_5z ))

# ########################
# Plots genes !
# region 1
_start, _end = _region5k[1], _region5k[2]
_ax = axs["genes"]
#
_gfs_fwd = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **fwd_inact_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_fwd, _region5k), pad=7_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_rev = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **rev_inact_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_rev, _region5k), pad=7_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_fwd.plot(ax=_ax, x_lim=(_start, _end), level_offset=-0.45, **plotargs)
_gfs_rev.plot(ax=_ax, x_lim=(_start, _end), level_offset=0.45, **plotargs)
#
_gfs_fwd = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **fwd_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_fwd_act, _region5k), pad=7_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_rev = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **rev_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_rev_act, _region5k), pad=7_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_fwd.plot(ax=_ax, x_lim=(_start, _end), level_offset=-0.45, **plotargs)
_gfs_rev.plot(ax=_ax, x_lim=(_start, _end), level_offset=0.45, **plotargs)
_ax.set_ylim(-1,1)
_ax.set_axis_on()


_start, _end = _region5k_zoom_B[1], _region5k_zoom_B[2]
_ax = axs["genes_zoom"]
_gfs_fwd = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **fwd_inact_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_fwd, _region5k_zoom_B), pad=7_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_rev = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **rev_inact_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_rev, _region5k_zoom_B), pad=7_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_fwd.plot(ax=_ax, x_lim=(_start, _end), level_offset=-0.45, **plotargs)
_gfs_rev.plot(ax=_ax, x_lim=(_start, _end), level_offset=0.45, **plotargs)
# active noiw ...
_gfs_fwd = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **fwd_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_fwd_act, _region5k_zoom_B), pad=7_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_rev = GraphicRecord(
    sequence_length=(_end-_start+1),
    features=[
        GraphicFeature(_row.start, _row.end, **rev_args) for _row in \
        bioframe.merge(
            bioframe.expand(bioframe.select(_rev_act, _region5k_zoom_B), pad=7_500),
            min_dist = 20_000,
        ).itertuples(index=False)
    ],
)
_gfs_fwd.plot(ax=_ax, x_lim=(_start, _end), level_offset=-0.45, **plotargs)
_gfs_rev.plot(ax=_ax, x_lim=(_start, _end), level_offset=0.45, **plotargs)
_ax.set_ylim(-1,1)
_ax.set_axis_on()


########################################
for k, ax in axs.items():
    ax.set_xticks([])
    ax.set_yticks([])


hm, hmkwargs = get_hm_double(clrM, clrP, _i1, _i2, **vlims_dict["50"])
hmkwargs["interpolation"] = "gaussian"
hmkwargs["interpolation_stage"] = "rgba"
axs["hmap"].imshow(hm, **hmkwargs)


# _i1_A_inset, _i2_A_inset
# _i1_B_inset, _i2_B_inset
_rec = Rectangle(
    (_i1_A_inset, _i1_B_inset),
    size_A, size_B,
    **patch_kwargs,
)
# draw those box and lines ...
axs["hmap"].add_patch(_rec)


# _i1_A_inset, _i2_A_inset
# _i1_B_inset, _i2_B_inset
_rec = Rectangle(
    (_i1_B_inset, _i1_A_inset),
    size_B, size_A,
    **patch_kwargs,
)
# draw those box and lines ...
axs["hmap"].add_patch(_rec)


vlims_dict["10"] = dict(vmin=0.00005, vmax=0.002)
hm, hmkwargs = get_hm(clrM_zoom, _i1_A, _i2_A, _i1_B, _i2_B, **vlims_dict["10"])
hmkwargs["interpolation"] = "antialiased"
hmkwargs["interpolation_stage"] = "data"
axs["hmap_zoom_up"].imshow(hm, **hmkwargs)

hm, hmkwargs = get_hm(clrP_zoom, _i1_A, _i2_A, _i1_B, _i2_B, **vlims_dict["10"])
hmkwargs["interpolation"] = "antialiased"
hmkwargs["interpolation_stage"] = "data"
axs["hmap_zoom_bot"].imshow(hm, **hmkwargs)
# _i1_zA, _i2_zA
# _i1_zB, _i2_zB


_track_factor=10_000
_bin_factor = 500/(_region5k_zoom_B[2] - _region5k_zoom_B[1])
#do tracks in a cycle ...
_track, _bin_factor, _vlims, _ax1, _ax2, _color = (
    bws['H3K27ac'],
    2*_bin_factor*0.75,
    (0.001, 75),
    axs["k27ac"],
    axs["k27ac_zoom"],
    "red",
)

_bins1 = int( _bin_factor*( _region5k[2] - _region5k[1] ) )
_bins2 = int( _bin_factor*( _region5k_zoom_B[2] - _region5k_zoom_B[1] ) )
track = bbi.fetch(_track, _region5k[0], _region5k[1], _region5k[2], bins=_bins1, summary="mean", missing=0.0, oob=0.0)
track_zoom_B = bbi.fetch(_track, _region5k_zoom_B[0], _region5k_zoom_B[1], _region5k_zoom_B[2], bins=_bins2, summary="mean", missing=0.0, oob=0.0)
_ax1.fill_between(
    x=np.arange(len(track)),
    y1=0,
    y2=track,
    linewidth=0.5,
    color=_color,
)
_ax1.set_xlim(0, _bins1)
_ax1.set_ylim(*_vlims)
_ax2.fill_between(
    x=np.arange(len(track_zoom_B)),
    y1=0,
    y2=track_zoom_B,
    linewidth=0.5,
    color=_color,
)
_ax2.set_xlim(0, _bins2)
_ax2.set_ylim(*_vlims)

# plot MCDs ...
mcd_kwargs = dict(color="black", alpha=1,ec=None)
# doing that using clr.offset and clr.extent functionality:
_anchors["bin_id"] = _anchors[['chrom', 'peak_start', 'peak_end']].apply(clrM.offset, axis=1, result_type="expand")
_anchors["bin_width"] = _anchors[['chrom', 'peak_start', 'peak_end']] \
    .apply(clrM.extent, axis=1, result_type="expand") \
    .apply(np.diff, axis=1, result_type="expand")[0]
rectangles_at_anchors(_anchors, clrM.extent(_region5k), axs["mcd"], ext_width=0.0, **mcd_kwargs)
axs["mcd"].set_xlim(0, _i2-_i1)

# vertical ones ...
rectangles_at_anchors_vert(_anchors, clrM.extent(_region5k), axs["mcd_vert"], ext_width=0.0, **mcd_kwargs)
axs["mcd_vert"].set_ylim(0, _i2-_i1)
axs["mcd_vert"].invert_yaxis()

# doing that using clr.offset and clr.extent functionality:
_anchors["bin_id"] = _anchors[['chrom', 'peak_start', 'peak_end']].apply(clrM_zoom.offset, axis=1, result_type="expand")
_anchors["bin_width"] = _anchors[['chrom', 'peak_start', 'peak_end']] \
    .apply(clrM_zoom.extent, axis=1, result_type="expand") \
    .apply(np.diff, axis=1, result_type="expand")[0]
rectangles_at_anchors(_anchors, clrM_zoom.extent(_region5k_zoom_B), axs["mcd_zoom"], ext_width=0.0, **mcd_kwargs)
axs["mcd_zoom"].set_xlim(0, _i2_B-_i1_B)


# vertical ones ...
rectangles_at_anchors_vert(_anchors, clrM_zoom.extent(_region5k_zoom_A), axs["mcd_zoom_up"], ext_width=0.0, **mcd_kwargs)
axs["mcd_zoom_up"].set_ylim(0, _i2_A-_i1_A)
axs["mcd_zoom_up"].invert_yaxis()
rectangles_at_anchors_vert(_anchors, clrM_zoom.extent(_region5k_zoom_A), axs["mcd_zoom_bot"], ext_width=0.0, **mcd_kwargs)
axs["mcd_zoom_bot"].set_ylim(0, _i2_A-_i1_A)
axs["mcd_zoom_bot"].invert_yaxis()

axs["genes"].axis("off")
axs["k27ac"].axis("off")
axs["evs"].axis("off")

axs["genes_zoom"].axis("off")
axs["k27ac_zoom"].axis("off")
axs["evs_zoom"].axis("off")



# it's 25 actually - but whatever
_vmin, _vmax = vlims_dict["50"]["vmin"], vlims_dict["50"]["vmax"]
plt.colorbar(
    cm.ScalarMappable(norm=LogNorm(vmin=_vmin, vmax=_vmax), cmap=mycmap),
    cax=cbar,
    orientation="horizontal",
)
cbar.xaxis.set_visible(True)
_ticks_power = range(
    np.ceil(np.log10(_vmin)).astype(int),
    np.floor(np.log10(_vmax)).astype(int)+1,
)
cbar.set_xticks([np.power(10.,_p) for _p in _ticks_power])
cbar.set_xticklabels(['$\mathdefault{10^{%i}}$' % l for l in _ticks_power])
cbar.xaxis.set_tick_params(labelsize=6, pad=0.1, length=2)
cbar.minorticks_off()


# it's 25 actually - but whatever
_vmin, _vmax = vlims_dict["10"]["vmin"], vlims_dict["10"]["vmax"]
plt.colorbar(
    cm.ScalarMappable(norm=LogNorm(vmin=_vmin, vmax=_vmax), cmap=mycmap),
    cax=cbar_zoom,
    orientation="horizontal",
)
cbar_zoom.xaxis.set_visible(True)
_ticks_power = range(
    np.ceil(np.log10(_vmin)).astype(int),
    np.floor(np.log10(_vmax)).astype(int)+1,
)
cbar_zoom.set_xticks([np.power(10.,_p) for _p in _ticks_power])
cbar_zoom.set_xticklabels(['$\mathdefault{10^{%i}}$' % l for l in _ticks_power])
cbar_zoom.xaxis.set_tick_params(labelsize=6, pad=0.1, length=2)
cbar_zoom.minorticks_off()


plt.savefig("Fig5K.svg", dpi=300)
